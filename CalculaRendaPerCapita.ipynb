# %%
### Calcula Renda Per Capita
Dados utilizados levando em consideração o Dicionário de campos do ENEM 2019.
- PS: Para funcionar, precisa ter um dataframe na variável dados
- PS2: Para o cálculo, foi considerado o teto de cada item. Para famílias que tem renda > que 19.960, foi considerado um valor de 24.950, seguindo o mesmo padrão de aumento.
- PS3: Tabela com descritivo dos valores usados:
![image.png](data:image/png;base64,...)
- PS4: O resultado do cálculo per cápita é arredondado.
- PS5: Prêmio que vou ganhar da Imersão de dados

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)

# %%
def geraListaPerCapita():
 
    quantidadeERenda = dados[["Q005","Q006"]]
    Q006RendaMaxima = {'A': 0,'B': 998,'C': 1497,'D': 1996,'E': 2495,'F': 2994,'G': 3992,'H': 4990,'I': 5988,'J': 6986,'K': 7984,'L': 8982,'M': 9980,'N': 11976,'O': 14970,'P': 19960,'Q': 24950}
    listaPerCapita = list()
    for quantidade, renda in quantidadeERenda.values:
        listaPerCapita.append(round(Q006RendaMaxima[renda]/quantidade))
    return listaPerCapita

dados['RENDA_PER_CAPITA'] = geraListaPerCapita()

# %%
dados['RENDA_PER_CAPITA'].value_counts()
# Out:
# 499     19370
# 250     10918
# 374      9725
# 333      8638
# 998      8137
#         ...
# 537         1
# 1089        1
# 1152        1
# 473         1
# 817         1
# Name: RENDA_PER_CAPITA, Length: 125, dtype: int64
